# %%
source("queuemodel.R")

# %%
hist(replicate(1000,mean(replicate(100,queuemodel(3,10,3)))), freq = F, breaks = 20)
# Out:
# Plot with title 鈥淗istogram of replicate(1000, mean(replicate(100, queuemodel(3, 10, 3))))鈥�

# %%
hist(replicate(1000,mean(replicate(100,queuemodel(4,10,4)))), freq = F, breaks = 20)
# Out:
# Plot with title 鈥淗istogram of replicate(1000, mean(replicate(100, queuemodel(4, 10, 4))))鈥�

# %%
hist(replicate(1000,mean(replicate(100,queuemodel(5,10,5)))), freq = F, breaks = 20)
# Out:
# Plot with title 鈥淗istogram of replicate(1000, mean(replicate(100, queuemodel(5, 10, 5))))鈥�

# %%
hist(replicate(1000,mean(replicate(100,queuemodel(50,100,50)))), freq = F, breaks = 20)
# Out:
# Plot with title 鈥淗istogram of replicate(1000, mean(replicate(100, queuemodel(50, 100, 50))))鈥�

# %% [markdown]
# $\lambda$
